# %% [markdown]
# # 🧪 Lab 6: Reflection and Challenge – DQN, Double DQN, Dueling, DRQN

# %% [markdown]
# ## 💡 Instructions
# Answer all questions in the cells provided. Each response should be at least 50 characters. Autograders will validate your answers.

# %% [markdown]
# ### ❓ Q1: What is the main limitation of standard DQN when applied to partially observable environments?

# %%
# POINTS: 2
q1_dqn_limitation = '''
Your answer here
'''

# %%
# ✅ Autograder for q1_dqn_limitation
try:
    assert isinstance(q1_dqn_limitation, str)
    assert len(q1_dqn_limitation.strip()) > 50
    print('✔ Answer OK')
except Exception as e:
    print('❌', e)

# %% [markdown]
# ### ❓ Q2: Why does using both a target network and experience replay help stabilize DQN training?

# %%
# POINTS: 2
q2_target_experience = '''
Your answer here
'''

# %%
# ✅ Autograder for q2_target_experience
try:
    assert isinstance(q2_target_experience, str)
    assert len(q2_target_experience.strip()) > 50
    print('✔ Answer OK')
except Exception as e:
    print('❌', e)

# %% [markdown]
# ### ❓ Q3: What is the intuition behind using Double DQN? How does it differ from the original DQN update?

# %%
# POINTS: 2
q3_double_dqn = '''
Your answer here
'''

# %%
# ✅ Autograder for q3_double_dqn
try:
    assert isinstance(q3_double_dqn, str)
    assert len(q3_double_dqn.strip()) > 50
    print('✔ Answer OK')
except Exception as e:
    print('❌', e)

# %% [markdown]
# ### ❓ Q4: Describe the advantage of Dueling DQN architecture in environments with many similar-valued actions.

# %%
# POINTS: 2
q4_dueling_advantage = '''
Your answer here
'''

# %%
# ✅ Autograder for q4_dueling_advantage
try:
    assert isinstance(q4_dueling_advantage, str)
    assert len(q4_dueling_advantage.strip()) > 50
    print('✔ Answer OK')
except Exception as e:
    print('❌', e)

# %% [markdown]
# ### ❓ Q5: Compare the input observations used in Lab 6.1 (bandits) vs. Labs 6.3–6.5 (Atari games). What preprocessing is done?

# %%
# POINTS: 2
q5_preprocessing = '''
Your answer here
'''

# %%
# ✅ Autograder for q5_preprocessing
try:
    assert isinstance(q5_preprocessing, str)
    assert len(q5_preprocessing.strip()) > 50
    print('✔ Answer OK')
except Exception as e:
    print('❌', e)
